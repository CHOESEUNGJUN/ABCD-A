# %% [markdown]
# <a href="https://colab.research.google.com/github/CHOESEUNGJUN/ABCD-A/blob/20250307/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EC%B4%88__20250307.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
watch=100000
a='pig'
b='dad'

print(a)
print(b)
print(watch)
print(a+b)
print(a+' '+b)
# Out:
# pig
# dad
# 100000
# pigdad
# pig dad

# %%
a = 10
a,b = (10,20) #튜플을 이용하여 값을 할당
[a,b] = [10,20] # 리스트를 이용하여 값을 할당
a = b = 10 # a와 b에 똑값은 값을 할당 하고 싶을 때 사용
a = None #비어 있는 변수를 만들고 싶을 때 사용

# %%
a = 10
b = 2000
a,b = b,a #a변수와 b변수를 교환
print(a,b)
# Out:
# 2000 10

# %%
aa = [10, 20, 30]
bb = aa
aa[0] = 200 #(aa 변수의 0번째 10을 -> 200 으로 변경
print(bb) #aa = bb 이기에 bb = aa라서 bb 출력 해도 문제가 없다.
# Out:
# [200, 20, 30]

# %%
print("Hello word") #문자열을 출력
print(1) #프린트 1을 출력

a = 3

print(a) # 변수를 출력
# Out:
# Hello word
# 1
# 3

# %%
a = 10
print("a" + str(a)) #str문은 숫자를 문자열로 바꿔주는 함수
print("a=", a) # 문자와 숫자를 표시하기 위해서는 ',' 콤마 사용
print("a={}".format(a)) # format함수사용
# Out:
# a10
# a= 10
# a=10

# %%
#dat1
a = [10, 20, 30]
b = 1
c = 2
print(a)
print("a={}".format(a)) #a 포멧값
print("b={}".format(b)) #b 포멧값
print("a={}, b={}, c{}".format(a, b, c))
# Out:
# [10, 20, 30]
# a=[10, 20, 30]
# b=1
# a=[10, 20, 30], b=1, c2
